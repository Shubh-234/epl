# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1     1
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0     0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0     0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0     0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0     0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (950, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester City             76
# Manchester United           76
# Newcastle United            76
# Liverpool                   76
# Arsenal                     76
# Wolverhampton Wanderers     38
# Leeds United                38
# Leicester City              38
# Everton                     38
# Nottingham Forest           38
# Bournemouth                 38
# West Ham United             38
# Crystal Palace              38
# Chelsea                     38
# Fulham                      38
# Brentford                   38
# Tottenham Hotspur           38
# Aston Villa                 38
# Brighton and Hove Albion    38
# Southampton                 38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D   2   2
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D   2   2
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D   1   1
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D   1   1
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L   1   2
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 49  2023-05-15  20:00  Premier League  Matchweek 36  Mon  Away      W   3   0
# 50  2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 50  2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 51  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      D   4   4
# 51  2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      D   4   4
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     25
# Matchweek 30    25
# Matchweek 23    25
# Matchweek 12    25
# Matchweek 24    25
# Matchweek 25    25
# Matchweek 26    25
# Matchweek 27    25
# Matchweek 29    25
# Matchweek 31    25
# Matchweek 2     25
# Matchweek 33    25
# Matchweek 34    25
# Matchweek 28    25
# Matchweek 35    25
# Matchweek 36    25
# Matchweek 37    25
# Matchweek 32    25
# Matchweek 22    25
# Matchweek 21    25
# Matchweek 7     25
# Matchweek 20    25
# Matchweek 3     25
# Matchweek 4     25
# Matchweek 5     25
# Matchweek 6     25
# Matchweek 8     25
# Matchweek 9     25
# Matchweek 10    25
# Matchweek 11    25
# Matchweek 13    25
# Matchweek 14    25
# Matchweek 15    25
# Matchweek 16    25
# Matchweek 17    25
# Matchweek 18    25
# Matchweek 19    25
# Matchweek 38    25
# Name: count, dtype: int64

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L   1   3
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L   3   4
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L   0   2
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L   1   3
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D   4   4
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
#n_estimators is the number of decision trees you wish to train
#the larger the number the longer the algorithm will take to execute but it will also be more accurate
#min_samples: no of samples we wish to take,the higher the number the least chance of overfit

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
#fitting the predictors in the random forest model to predict that target is 0 or 1(lose or win)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.590316573556797

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          208  101
# 1          119  109

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.5190476190476191

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
def rolling_averages(group,cols,new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3,closed = "left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group
#compute the stats of the previous 3 matchweeks of that team to predict how that team will perform in that upcoming match
#we use closed = ="left" because we do not want to take current matchweek data(future data) into consideration
#drop na dispose the null values encountered

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#take the macthes dataset by team,assign a dataframe to each team 
#and apply and compute the rolling averaged on each team dataframe

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 1  2022-08-13  15:00  Premier League   Matchweek 2
#                         2  2022-08-20  17:30  Premier League   Matchweek 3
#                         2  2022-08-20  17:30  Premier League   Matchweek 3
#                         3  2022-08-27  17:30  Premier League   Matchweek 4
#                         3  2022-08-27  17:30  Premier League   Matchweek 4
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#                         41 2023-05-13  15:00  Premier League  Matchweek 36
#                         42 2023-05-20  15:00  Premier League  Matchweek 37
#                         43 2023-05-28  16:30  Premier League  Matchweek 38
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   2
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W   3   0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W   3   0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2   1
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 39 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0   6
# 40 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1   0
# 41 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0   2
# 42 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 43 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   5
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   2
# 1   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W   3   0
# 2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W   3   0
# 3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2   1
# 4   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 885 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0   6
# 886 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1   0
# 887 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0   2
# 888 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 889 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   5
#
# ...

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5706521739130435

# %%
combined
# Out:
#      actual  predicted
# 29        0          1
# 30        0          1
# 31        1          1
# 32        1          1
# 33        1          0
# ..      ...        ...
# 885       0          0
# 886       1          0
# 887       0          0
# 888       0          0
# 889       0          0
#
# [537 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date","team","opponent","result"]],left_index = True,right_index = True)

# %%
combined
# Out:
#      actual  predicted       date                     team        opponent  \
# 29        0          1 2023-01-03                  Arsenal   Newcastle Utd
# 30        0          1 2023-01-03                  Arsenal   Newcastle Utd
# 31        1          1 2023-01-15                  Arsenal       Tottenham
# 32        1          1 2023-01-15                  Arsenal       Tottenham
# 33        1          0 2023-01-22                  Arsenal  Manchester Utd
# ..      ...        ...        ...                      ...             ...
# 885       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 886       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 887       0          0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 888       0          0 2023-05-20  Wolverhampton Wanderers         Everton
# 889       0          0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#     result
# 29       D
# 30       D
# 31       W
# 32       W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#      actual  predicted       date                     team        opponent  \
# 29        0          1 2023-01-03                  Arsenal   Newcastle Utd
# 30        0          1 2023-01-03                  Arsenal   Newcastle Utd
# 31        1          1 2023-01-15                  Arsenal       Tottenham
# 32        1          1 2023-01-15                  Arsenal       Tottenham
# 33        1          0 2023-01-22                  Arsenal  Manchester Utd
# ..      ...        ...        ...                      ...             ...
# 885       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 886       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 887       0          0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 888       0          0 2023-05-20  Wolverhampton Wanderers         Everton
# 889       0          0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#     result new_team
# 29       D  Arsenal
# 30       D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2023-01-03                  Arsenal
# 1           0            1 2023-01-03                  Arsenal
# 2           0            1 2023-01-03                  Arsenal
# 3           0            1 2023-01-03                  Arsenal
# 4           1            1 2023-01-15                  Arsenal
# ..        ...          ...        ...                      ...
# 639         0            0 2023-05-13  Wolverhampton Wanderers
# 640         0            0 2023-05-13  Wolverhampton Wanderers
# 641         0            0 2023-05-20  Wolverhampton Wanderers
# 642         0            0 2023-05-28  Wolverhampton Wanderers
# 643         0            0 2023-05-28  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Newcastle Utd        D    Arsenal         0            0
# 1     Newcastle Utd        D    Arsenal         0            1
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    100
# 0     70
# Name: count, dtype: int64

# %%
100/170
# Out:
# 0.5882352941176471
